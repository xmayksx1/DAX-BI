# %% [markdown]
# <a href="https://colab.research.google.com/github/xmayksx1/DAX-BI/blob/main/Cubo_Venta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
    import pyodbc
    import pandas as pd


    conexion = pyodbc.connect(
        'DRIVER={SQL Server};'
        'SERVER=172.18.1.46;'
        'DATABASE=DWH;'
        'UID=CUBOS;'
        'PWD=#cUb05@c3r3@1'
    )


    query = "SELECT BarraUnidad, Documento, ZGZona, FECHAFACTURA, FANOMES, FANO, FMES, ZGDepartamento, CANALDISTRIBUCION, CodigoCliente, NombreCliente, ITMCodigo, ITMDescripcion, CantidadFacturada, Cajas, PesoNeto, MontoTotalDOL, Bonificado, CostoTotalDOL, CodigoVendedor FROM V001_CuboVentaInforLn WHERE ITMCodigo IN (300100233, 300100235, 300200093)"

    try:

        df = pd.read_sql(query, conexion)


        nombre_archivo = "Reporte_Ventas_2026.csv"
        df.to_csv(nombre_archivo, index=False, encoding='utf-8-sig')

        print(f"¡Éxito! El archivo ha sido exportado como: {nombre_archivo}")
        display(df.head())

    except Exception as e:
        print(f"Error al procesar la consulta o exportar: {e}")
    finally:
        conexion.close()
