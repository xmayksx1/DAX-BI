# %% [markdown]
# <a href="https://colab.research.google.com/github/xmayksx1/DAX-BI/blob/main/Ejecutar_Modelo_Semanal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python dashboard_demanda.py
